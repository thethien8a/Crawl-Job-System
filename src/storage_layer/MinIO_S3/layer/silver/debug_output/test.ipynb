# %%
import polars as pl

# Cấu hình hiển thị tối đa 1000 ký tự
pl.Config.set_fmt_str_lengths(1000)

# Chạy lại câu lệnh của bạn
pl.read_parquet("itviec_cleaned_2026-05-14.parquet").select("job_url").head(5)
# Out:
# shape: (5, 1)
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ job_url                                                                                          │
# │ ---                                                                                              │
# │ str                                                                                              │
# ╞══════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ https://itviec.com/it-jobs/data-analyst-data-division-mb-bank-2500?lab_feature=preview_jd_page   │
# │ https://itviec.com/it-jobs/chuyen-gia-phan-tich-du-lieu-senior-data-analyst-pvcombank-5212?lab_f │
# │ eature=preview_jd_page                                                                           │
# │ https://itviec.com/it-jobs/cv-cvcc-phan-tich-du-lieu-data-analyst-k-cntt-pvcombank-5054?lab_feat │
# ...
